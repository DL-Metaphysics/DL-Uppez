# %% [markdown]
# https://www.jianshu.com/p/4786dbc87008
#
# https://www.jianshu.com/p/22a872f52c7f
#
# https://blog.csdn.net/quiet_girl/article/details/80033951

# %% [markdown]
# # 一般推导

# %% [markdown]
# ## 单个样本

# %% [markdown]
# ### 前向传播推导

# %% [markdown]
# 下面使用一简单的例子介绍前向传播，如下图：
# ![20180422003908724.jpg](attachment:20180422003908724.jpg)
# 前向传播和我们平时的思维是一致的，即给出输入，通过一次次变换得到输出。

# %% [markdown]
# ### 反向传播推导

# %% [markdown]
# 参数的更新过程是算法结果不断优化的过程：输入数据，根据前向传播可以得到预测值，将预测值和真实值进行比较，得到损失函数，基于损失函数，更新参数，使得每一次的迭代过程损失函数都会减小，这就是更新的主要思想。
#
# 下面主要讲后向传播及其推理过程，两层神经网络的模型如下：
# ![20180519101635227.jpg](attachment:20180519101635227.jpg)
# 反向传播的过程就是从后向前更新参数的过程，更新参数的规则如下：
# ![QQ%E6%88%AA%E5%9B%BE20190724084917.png](attachment:QQ%E6%88%AA%E5%9B%BE20190724084917.png)
# 为了求取参数更新的公式，我们有如下的求导过程：
# ![QQ%E6%88%AA%E5%9B%BE20190724085008.png](attachment:QQ%E6%88%AA%E5%9B%BE20190724085008.png)

# %% [markdown]
# ## m个样本的梯度下降

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20190724085144.png](attachment:QQ%E6%88%AA%E5%9B%BE20190724085144.png)

# %% [markdown]
# # 向量化推导

# %% [markdown]
# ## 转化为向量化

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20190724085238.png](attachment:QQ%E6%88%AA%E5%9B%BE20190724085238.png)
# ![QQ%E6%88%AA%E5%9B%BE20190724085252.png](attachment:QQ%E6%88%AA%E5%9B%BE20190724085252.png)
# ![QQ%E6%88%AA%E5%9B%BE20190724085309.png](attachment:QQ%E6%88%AA%E5%9B%BE20190724085309.png)
# ![QQ%E6%88%AA%E5%9B%BE20190724085410.png](attachment:QQ%E6%88%AA%E5%9B%BE20190724085410.png)

# %% [markdown]
# ## 伪代码

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20190724085451.png](attachment:QQ%E6%88%AA%E5%9B%BE20190724085451.png)
